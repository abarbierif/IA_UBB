# %% [markdown]
# <a href="https://colab.research.google.com/github/abarbierif/IA_UBB/blob/Project-Proposal/cifar10_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 EDA
#
#  The CIFAR-10 dataset consists of 60000 32x32 colour images in 10 classes, with 6000 images per class. There are 50000 training images and 10000 test images.

# %% [markdown]
# ### `libraries`

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import sys
import pandas as pd
import pickle

os.chdir('/content/drive/MyDrive/AI/IA_UBB/EDAs')
sys.path.append('../py_utils')

from data_loading import *
from data_visualization import *
from utils import *
from data_preprocessing import *

os.getcwd()
# Out:
# '/content/drive/MyDrive/AI/IA_UBB/EDAs'

# %%
os.listdir('./')
# Out:
# ['fashion_mnist_EDA.ipynb', 'cifar10_EDA.ipynb']

# %% [markdown]
# ### `load data`

# %%
X, y = load_data(source='tfds', to='ndarray', dataset='cifar10', dims=(32,32))
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.EFZQA5_3.0.2/cifar10-train.tfrecord*...:   0%|         …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.EFZQA5_3.0.2/cifar10-test.tfrecord*...:   0%|          …
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# ### `data distribution`

# %%
classes = {
    0:'airplane',
    1:'automobile',
    2:'bird',
    3:'cat',
    4:'deer',
    5:'dog',
    6:'frog',
    7:'horse',
    8:'ship',
    9:'truck'
}

y_labels = np.array([classes[i] for i in y])

classes_distribution(
    y_labels,
    figsize=(7,5),
    title='',
    hatch='',
    cmap=None,
    xlabel='clases',
    ylabel='n° de imágenes',
    labelrotation=60,
    facecolor='#e6e6e6',
    color='#6b6b6b'
)

# %% [markdown]
# ### `data visualization`

# %%
classes_distribution(
    y_labels,
    figsize=(10,5),
    title='',
    hatch='',
    cmap=None,
    xlabel='clases',
    ylabel='n° de imágenes',
    labelrotation=0,
    facecolor='#e6e6e6',
    color='#6b6b6b'
)

# %% [markdown]
# ### `data visualization`

# %%
display_data(
    source='ndarray',
    rows=2,
    cols=5,
    x=X,
    y=y_labels,
    display_mode='classes',
    figsize=(10,5)
)
