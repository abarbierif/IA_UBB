# %% [markdown]
# <a href="https://colab.research.google.com/github/abarbierif/IA_UBB/blob/Project-Proposal/fashion_mnist_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # `Fashion-MNIST`
#  is a dataset of [Zalando](https://jobs.zalando.com/tech/)'s article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. We intend `Fashion-MNIST` to serve as a direct **drop-in replacement** for the original [MNIST dataset](http://yann.lecun.com/exdb/mnist/) for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.

# %% [markdown]
# ### `libraries`

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import sys
import pandas as pd
import pickle

sys.path.append('/content/drive/MyDrive/AI/IA_UBB/py_utils')

from data_loading import *
from data_visualization import *
from utils import *
from data_preprocessing import *

os.chdir('/content/drive/MyDrive/AI/IA_UBB/EDAs')
os.getcwd()
# Out:
# '/content/drive/MyDrive/AI/IA_UBB/EDAs'

# %%
os.listdir('./')
# Out:
# ['fashion_mnist_EDA.ipynb']

# %% [markdown]
# ### `load data`

# %%
import mnist_reader
data_path = '/content/drive/MyDrive/datasets/fashion'
X_train, y_train = mnist_reader.load_mnist(data_path, kind='train')
X_test, y_test = mnist_reader.load_mnist(data_path, kind='t10k')

print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (60000, 784)
# y_train shape: (60000,)
# X_test shape: (10000, 784)
# y_test shape: (10000,)

# %%
X_train = [img.reshape(28,28) for img in X_train]
X_test = [img.reshape(28,28) for img in X_test]
y_train = list(y_train)
y_test = list(y_test)

X = np.array(X_train + X_test)
y = np.array(y_train + y_test)

print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
# Out:
# X shape: (70000, 28, 28)
# y shape: (70000,)

# %% [markdown]
# ### `data distribution`

# %%
classes = {
    0:'T-shirt/top',
    1:'Trouser',
    2:'Pullover',
    3:'Dress',
    4:'Coat',
    5:'Sandal',
    6:'Shirt',
    7:'Sneaker',
    8:'Bag',
    9:'Ankle boot'
}

y_labels = [classes[i] for i in y]

classes_distribution(
    y_labels,
    figsize=(7,5),
    title='',
    hatch='',
    cmap=None,
    xlabel='clases',
    ylabel='n° de imágenes',
    labelrotation=60,
    facecolor='#e6e6e6',
    color='#6b6b6b'
)

# %% [markdown]
# ### `data visualization`

# %%
display_data(
    source='ndarray',
    rows=2,
    cols=5,
    x=X,
    y=y,
    display_mode='classes',
    figsize=(20,10),
    cmap='gray',
    layout='constrained'
)
